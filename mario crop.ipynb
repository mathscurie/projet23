# %%
from PIL import *

img=Image.open('mario-sprite-png-4.jpg')
img.crop((300,80,400,160)).save('image1.png')

# %%
img1=Image.open('image1.png')
img1.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x80 at 0xF7CB90>

# %%
import basthon
basthon.download('image1.png')
